# %%
import os
import sys
import json
from pyld import jsonld
from lxml.html.soupparser import fromstring
import re
import urllib
import PyPDF4
# response = urllib2.urlopen('http://www.example.com/')
# html = response.read()

folderDir = 'USC'
fileList = os.listdir(folderDir)

f = open('usc.jsonld')
jsonObject = json.load(f)
f.close()

nextId = jsonObject['nextId']
# Out:
# F:\installation\python36\lib\site-packages\requests\__init__.py:80: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
for obj in jsonObject['@graph']:
    if (obj['@type']=='ckb:Section') and ('ckb:Syllabus' in obj.keys()) and ('PDF'==obj['ckb:Syllabus']):
        tempPdfDir = 'USC/syllabus/'+obj['ckb:sectionID']+'.pdf'
        f = open(tempPdfDir,'rb')
        try:
            pdfReader = PyPDF4.PdfFileReader(f)
            m = re.findall(r'(?i)office hour[s]?[:]?[\s\n]*?([\d\w\-\.\,\:\t]+[\d]*)',pdfReader.getPage(0).extractText())
            if len(m)>0 and len(' '.join(m))>2:
#                 print(' '.join(m))
#                 print(tempPdfDir)
                obj['ckb:OfficeHour'] = ' '.join(m)
            m = re.findall(r'[e|E][-]?[m|M]ail[:]?[\s]*?([\w\.-]+@[\w\.-]+)',pdfReader.getPage(0).extractText())
            if len(m)>0:
                obj['ckb:email'] = m[0]
#                 print(m[0])
#                 print(tempPdfDir)
        except:
            continue
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1801]
# PdfReadWarning: Superfluous whitespace found in object header b'1' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'2' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'3' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'63' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'66' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'69' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'72' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'75' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'78' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'81' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'61' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'47' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'50' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'108' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'111' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'114' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'117' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'120' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'123' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'126' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'45' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'71' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'74' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'77' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'88' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'91' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'94' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'97' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'100' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'32' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'51' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'70' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'73' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'76' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'79' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'82' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'85' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'96' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'107' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'110' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'121' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'124' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'127' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'139' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'143' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'146' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'149' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'152' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'155' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'30' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'54' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'65' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'84' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'87' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'90' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'93' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'52' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'35' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'46' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'57' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'68' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'44' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'49' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'60' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'99' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'102' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'113' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'130' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'141' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'144' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'147' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'150' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'153' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'164' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'48' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'28' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'55' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'59' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'62' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'53' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'40' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'38' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'22' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'104' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'20' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'33' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'36' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'39' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'42' b'0' [pdf.py:1731]
# PdfReadWarning: Superfluous whitespace found in object header b'64' b'0' [pdf.py:1731]

# %%
syllabusList = os.listdir('USC/syllabus')
for fileName in syllabusList:
    if '.pdf' in fileName:
#         print(fileName)

        f = open('USC/syllabus/'+fileName,'rb')
        try:
            pdfReader = PyPDF4.PdfFileReader(f)
            m = re.findall(r'(?i)office hour[s]?[:]?[\s\n]*?([\d\w\-\.\,\:\t]+[\d]*)',pdfReader.getPage(0).extractText())
            if len(m)>0 and len(' '.join(m))>2:
                print(' '.join(m))
#                 print(fileName)
            m = re.findall(r'[e|E][-]?[m|M]ail[:]?[\s]*?([\w\.-]+@[\w\.-]+)',pdfReader.getPage(0).extractText())
            if len(m)>0:
                print(''.join(m))
#                 print(fileName)
        except:
            continue
# Out:
# b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\